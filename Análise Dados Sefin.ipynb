# %% [markdown]
# #### SEFIN - 2018 BASE TERRITORIAL
# - Nº LINHAS: 453735
# - COLUNAS: 34
# - DISTRITOS: 77 (???)
#
# ------------------
# #### SEFIN - 2010 BASE EDIFICAÇÕES
# - Nº LINHAS: 1.210.876
# - COLUNAS: 6
# - DISTRITOS: DO 31 AO 39 (???)
# ------------------
# #### TOTAL DE BAIRROS DE FORTALEZA = 121
# BAIRROS POR REGINAL:
# - reginal 1 = 15 bairros
# - regional 2 = 20 bairros
# - regional 3 = 17 bairros
# - reginal 4 = 20 bairros
# - regional 5 = 18 bairros
# - regional 6 = 30 bairros
# - SERCEFOR = 1 bairro
# ------------------
# #### IBGE:
# - 3021 ZONAS CENSITÁRIAS EM FORTALEZA (13 MIL E TANTOS NO CEARÁ)
# - 5 DISTRITOS
# - 7 REGIONAIS
# - 12 SUB-DISTRITOS
# - 121 BAIRROS
#
# DISTRITOS (IBGE):
# - 1. PARANGABA
#     - (1) Paranganba
# - 2. MONDUBIM
#     - (2) Prefeito José Walter
#     - (3) Mondubim
#     - (4) Conjunto Ceará ???
# - 3. MESSEJANA
#     - (5) Messejana
#     - (6) Cidade dos Funcionários
# - 4. ANTONIO BEZERRA
#     - (7) Conjunto Ceará ???
#     - (8) Antonio Bezerra ???
# - 5. FORTALEZA
#     - (9) Mucuripe
#     - (10) Centro
#     - (11) Barra do Ceará
#     - (12) Antonio Bezerra ???

# %% [markdown]
# ### BIBLIOTECAS

# %%
import geopandas as gpd
import matplotlib as plt

# %% [markdown]
# ## SEFIN BASE TERRITORIAL 2018

# %% [markdown]
# ABRINDO O ARQUIVO

# %%
sefin_df = gpd.read_file('/home/nico/Área de Trabalho/Projeto Combate Covid/SEFIN - shp/sefin_base_territorial_2018_06.shp')

# %% [markdown]
# PLOTANDO OS ATRIBUTOS

# %%
# list(sefin_df) ou sefin_df.columns
sefin_df.columns
# Out:
# Index(['distrito', 'quadra', 'lote', 'tipoimovel', 'ocupacao', 'qtdautonom',
#        'qtdfrentes', 'testada', 'area_terre', 'areaediflo', 'lazer',
#        'desportivo', 'religioso', 'institucio', 'transporte', 'comunicaca',
#        'agricultur', 'saude', 'hotelaria', 'fechado', 'firmaindiv', 'sem',
#        'residencia', 'comercial', 'prestserv', 'industrial', 'instrucao',
#        'temelevado', 'pavimentos', 'vv_unit_te', 'vv_terreno', 'vv',
#        'a_edificad', 'geometry'],
#       dtype='object')

# %% [markdown]
# * distrito = Distrito Censitário (?)
# * quadra = Contagem por distrito (distrito 1 tem 65 quadras, por exemplo)
# * lote = Número do endereço, aparentemente.
# * tipoimovel = "Predial", "Territorial" (praças, eu suspeito, mas parece desatualizado)
# * ocupação = "Condominio Vertical", "Normal", "Não informado".
# * qtdautonom = Quantidade de unidades autonomas em um lote.
# * qtdfrentes = Quantidade de frentes de lotes.
# * testada = Largura da frente do lote.
# * area_terre = Área do terreno.
# * areaediflo = Área construída da edificação.
# ---------------
# ### CATEGORIAS DE OCUPAÇÃO (área respectiva em m²)
# * lazer = Lazer
# * desportivo = Desportivo
# * religoso = Religioso
# * institucio = Institucional
# * transporte = Transporte
# * comunicaca = Comunicação
# * agricultur = Agricultura
# * saude = Saúde
# * hotelaria = Hotelaria
# * fechado =
# * firmaindivid = Firma Individual
# * sem =
# * residencia = Residencial
# * comercial = Comercial
# * prestserv = Prestação de Serviço
# * industrial = Industria
# * instrução = Educação (?)
# ---------------
# * temelevado = Possui de elevador (?)
# * pavimentos = Quantidade de Pavimentos
# * vv_unit_te = Valor Venal Unitário (m²) do Terreno (?)
# * vv_terreno = Valor Venal do Terreno (?)
# * vv = Valor Venal da Pripriedade Contruída
# * a_edificad = Área da Edificação (a mesma da areaediflo)
# * geometry = Coordenadas do Polígono

# %%
# Mostrar a tabela apenas com as colunas desejadas
sefin_df[['distrito', 'lote', 'tipoimovel', 'ocupacao', 'qtdautonom', 'comercial']]
# Out:
#         distrito  lote   tipoimovel             ocupacao  qtdautonom  \
# 0              1     1         None        Nao informado           0
# 1              1    68      Predial  Condominio Vertical          21
# 2              1   119      Predial        Nao informado           1
# 3              1   209      Predial        Nao informado           1
# 4              1   260      Predial        Nao informado           1
# ...          ...   ...          ...                  ...         ...
# 453730        77    57         None        Nao informado           0
# 453731        77   231         None        Nao informado           0
# 453732        77    38      Predial        Nao informado           1
# 453733        77    57  Territorial               Normal           1
# 453734        77   350  Territorial               Normal           1
#
#         comercial
# 0             NaN
# 1          938.00
# 2        11321.00
# 3             NaN
# 4         3160.00
# ...           ...
# 453730        NaN
# 453731        NaN
# 453732     792.52
# 453733        NaN
# 453734        NaN
#
# [453735 rows x 6 columns]

# %%
sefin_df.plot()

# %%
sefin_df.loc[10,'geometry']

# %%
sefin_df
# Out:
#         distrito  quadra  lote   tipoimovel             ocupacao  qtdautonom  \
# 0              1       1     1         None        Nao informado           0
# 1              1       1    68      Predial  Condominio Vertical          21
# 2              1       1   119      Predial        Nao informado           1
# 3              1       1   209      Predial        Nao informado           1
# 4              1       1   260      Predial        Nao informado           1
# ...          ...     ...   ...          ...                  ...         ...
# 453730        77      21    57         None        Nao informado           0
# 453731        77      21   231         None        Nao informado           0
# 453732        77      22    38      Predial        Nao informado           1
# 453733        77      23    57  Territorial               Normal           1
# 453734        77      24   350  Territorial               Normal           1
#
#         qtdfrentes  testada  area_terre  areaediflo  ...  prestserv  \
# 0              1.0      0.0         0.0         NaN  ...        NaN
# 1              2.0     33.8       393.0     1047.00  ...        NaN
# 2              1.0     48.0       852.0    11321.00  ...        NaN
# 3              2.0     44.0      1161.6     8403.00  ...        NaN
# 4              2.0     48.0      1025.0     3160.00  ...        NaN
# ...            ...      ...         ...         ...  ...        ...
# 453730         1.0      9.0       233.0         NaN  ...        NaN
# 453731         1.0      5.4       152.0         NaN  ...        NaN
# 453732         1.0     38.0      1085.0      792.52  ...        NaN
# 453733         NaN     57.0       682.0         NaN  ...        NaN
# 453734         NaN    126.0      5970.0         NaN  ...        NaN
#
#         industrial  instrucao  temelevado  pavimentos  vv_unit_te  vv_terreno  \
# 0              NaN        NaN           0         NaN         NaN         NaN
# 1              NaN        NaN           0         3.0      763.37    14779.14
# 2              NaN        NaN           0        13.0      786.06   685628.02
# 3              NaN        NaN           0        12.0      540.67   650965.92
# 4              NaN        NaN           0         3.0      758.76   806730.02
# ...            ...        ...         ...         ...         ...         ...
# 453730         NaN        NaN           0         NaN         NaN         NaN
# 453731         NaN        NaN           0         NaN         NaN         NaN
# 453732         NaN        NaN           0         1.0     4894.06  5417026.03
# 453733         NaN        NaN           0         NaN     4894.06  3494057.85
# 453734         NaN        NaN           0         NaN         NaN         NaN
#
#                 vv  a_edificad  \
# 0              NaN         NaN
# 1        748848.40      1047.0
# 2       4978664.43     11321.0
# 3       6858766.20      8403.0
# 4       2364524.70      3160.0
# ...            ...         ...
# 453730         NaN         NaN
# 453731         NaN         NaN
# 453732  5910081.24         NaN
# 453733  3494057.85         NaN
# 453734         NaN         NaN
#
#                                                  geometry
# 0                                                    None
# 1       POLYGON ((552649.261 9587647.387, 552638.466 9...
# 2       POLYGON ((552644.850 9587684.590, 552630.621 9...
# 3       POLYGON ((552670.230 9587692.790, 552644.236 9...
# 4       POLYGON ((552644.850 9587684.590, 552644.236 9...
# ...                                                   ...
# 453730                                               None
# 453731                                               None
# 453732  POLYGON ((556964.330 9588497.147, 556964.676 9...
# 453733  POLYGON ((556657.161 9588379.232, 556654.004 9...
# 453734  POLYGON ((557711.218 9588599.666, 557697.380 9...
#
# [453735 rows x 34 columns]

# %%
sefin_df[sefin_df.distrito == 75]
# Out:
#         distrito  quadra  lote   tipoimovel ocupacao  qtdautonom  qtdfrentes  \
# 439271        75       1   960  Territorial   Normal           1         NaN
# 439272        75       1  1200  Territorial   Normal           1         NaN
# 439273        75       2  3252  Territorial   Normal           1         2.0
# 439274        75       2  6767  Territorial   Normal           1         4.0
# 439275        75       2  6768      Predial   Normal           1         4.0
# ...          ...     ...   ...          ...      ...         ...         ...
# 445196        75     237   280      Predial   Normal           1         1.0
# 445197        75     237   290      Predial   Normal           1         1.0
# 445198        75     237   300  Territorial   Normal           1         1.0
# 445199        75     237   309      Predial   Normal           1         1.0
# 445200        75     238   100  Territorial   Normal           1         NaN
#
#         testada  area_terre  areaediflo  ...  prestserv  industrial  \
# 439271   153.95    38628.19         NaN  ...        NaN         NaN
# 439272   237.21    42177.19         NaN  ...        NaN         NaN
# 439273   252.28    46616.19         NaN  ...        NaN         NaN
# 439274   528.76   124091.21         NaN  ...        NaN         NaN
# 439275   150.77    55335.00     2745.23  ...        NaN         NaN
# ...         ...         ...         ...  ...        ...         ...
# 445196     8.40      166.82       48.88  ...        NaN         NaN
# 445197    10.00      200.00       64.22  ...        NaN         NaN
# 445198    10.00      200.00         NaN  ...        NaN         NaN
# 445199    10.00      200.00       88.55  ...        NaN         NaN
# 445200   125.00     2950.00         NaN  ...        NaN         NaN
#
#         instrucao  temelevado  pavimentos  vv_unit_te  vv_terreno          vv  \
# 439271        NaN           0         NaN       31.59  1375142.77  1375142.77
# 439272        NaN           0         NaN         NaN         NaN         NaN
# 439273        NaN           0         NaN        7.85   463330.69   463330.69
# 439274        NaN           0         NaN       18.54  2744164.58  2744164.58
# 439275        NaN           0         1.0        7.85   542664.22  1017340.56
# ...           ...         ...         ...         ...         ...         ...
# 445196        NaN           0         1.0       15.73     2326.50    12741.16
# 445197        NaN           0         1.0       15.73     2812.47    16495.56
# 445198        NaN           0         NaN       18.54     3314.89     3314.89
# 445199        NaN           0         1.0       15.73     2812.47    27144.94
# 445200        NaN           0         NaN       42.04   129256.53   129256.53
#
#         a_edificad                                           geometry
# 439271         NaN  POLYGON ((552650.376 9572232.047, 552619.420 9...
# 439272         NaN  POLYGON ((552454.479 9572362.210, 552619.420 9...
# 439273         NaN                                               None
# 439274         NaN                                               None
# 439275         NaN                                               None
# ...            ...                                                ...
# 445196         NaN  POLYGON ((552206.660 9574762.880, 552208.910 9...
# 445197         NaN  POLYGON ((552202.810 9574745.311, 552215.050 9...
# 445198         NaN  POLYGON ((552222.400 9574754.090, 552229.850 9...
# 445199         NaN  POLYGON ((552222.664 9574728.837, 552217.440 9...
# 445200         NaN  POLYGON ((553062.570 9572913.791, 552962.597 9...
#
# [5930 rows x 34 columns]

# %% [markdown]
# ### SEFIN BASE EDIFICAÇÕES 2010

# %%
edific_df = gpd.read_file('/home/nico/Área de Trabalho/Projeto Combate Covid/SEFIN - shp/sefin_base_edificacoes_2010.shp')

# %%
edific_df
# Out:
#              gid    iq  distrito  altura   area  \
# 0        2937838  None        31     3.3   2.03
# 1        2937852  None        31     3.1  21.87
# 2        2938036  None        31     2.7  52.36
# 3        2938146  None        31     3.5  64.93
# 4        2938574  None        31     2.6   0.01
# ...          ...   ...       ...     ...    ...
# 1210871  2911847  None        39     3.1    NaN
# 1210872  2911848  None        39     4.9    NaN
# 1210873  2911849  None        39     3.3    NaN
# 1210874  2911850  None        39     3.2    NaN
# 1210875  2911851  None        39     3.9    NaN
#
#                                                   geometry
# 0        POLYGON ((545008.730 9581862.700, 545008.334 9...
# 1        POLYGON ((544896.240 9581873.460, 544895.860 9...
# 2        POLYGON ((544957.310 9581916.330, 544957.164 9...
# 3        POLYGON ((545029.270 9581942.700, 545027.540 9...
# 4        POLYGON ((544827.618 9582032.594, 544827.362 9...
# ...                                                    ...
# 1210871  POLYGON ((550280.590 9583289.810, 550278.140 9...
# 1210872  POLYGON ((550613.250 9583289.320, 550611.606 9...
# 1210873  POLYGON ((549520.590 9583283.510, 549519.880 9...
# 1210874  POLYGON ((549824.050 9583287.840, 549823.170 9...
# 1210875  POLYGON ((549354.730 9583288.150, 549356.870 9...
#
# [1210876 rows x 6 columns]

# %%
edific_df.loc[10,'geometry']

# %%
edific_df.plot(column='distrito',legend=True, cmap='jet', figsize=(10,10))

# %%
#SEPARANDO DISTRITO 31 edificação
edific_distrito_31 = edific_df[edific_df.distrito == 31]
edific_distrito_31.plot()

# %%
#SEPARANDO DISTRITO 32 edificação
edific_distrito_31 = edific_df[edific_df.distrito == 31]
edific_distrito_31.plot()

# %%
#SEPARANDO DISTRITO 31 - base territorial
territorial_distrito_31 = sefin_df[sefin_df.distrito == 31]
territorial_distrito_31.plot()

# %%
#SEPARANDO DISTRITO 1
territorial_distrito_1 = sefin_df[sefin_df.distrito == 1]
territorial_distrito_1.plot()

# %%
#territorial_distrito_1.to_file('/home/nico/Área de Trabalho/Projeto Combate Covid/SEFIN - shp/territorial_distrito_1.shp')

# %%
#SEPARANDO DISTRITO 2
territorial_distrito_2 = sefin_df[sefin_df.distrito == 2]
territorial_distrito_2.plot()

# %%
#SEPARANDO DISTRITO 3
territorial_distrito_3 = sefin_df[sefin_df.distrito == 3]
territorial_distrito_3.plot()
